# %% [markdown]
# **AbuseEval v1.0**

# %%
# /content/abuseval_offenseval_train.tsv

# %%
import pandas as pd

# Path to the TSV file
file_path = "/content/abuseval_offenseval_train.tsv"

# Load the TSV file into a Pandas DataFrame
dataset = pd.read_csv(file_path, sep='\t')

# Display the first few rows of the dataset
print(dataset.head())

# Display basic information about the dataset
print(dataset.info())
# Out:
#       id   abuse
# 0  86426  NOTABU
# 1  90194  NOTABU
# 2  16820  NOTABU
# 3  62688  NOTABU
# 4  43605  NOTABU
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13240 entries, 0 to 13239
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      13240 non-null  int64
#  1   abuse   13240 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 207.0+ KB
# None

# %%
dataset
# Out:
#           id   abuse
# 0      86426  NOTABU
# 1      90194  NOTABU
# 2      16820  NOTABU
# 3      62688  NOTABU
# 4      43605  NOTABU
# ...      ...     ...
# 13235  95338     EXP
# 13236  67210  NOTABU
# 13237  82921     IMP
# 13238  27429  NOTABU
# 13239  46552  NOTABU
#
# [13240 rows x 2 columns]

# %%
dataset.iloc[0]
# Out:
# id        86426
# abuse    NOTABU
# Name: 0, dtype: object

# %%
dataset.iloc[1]
# Out:
# id        90194
# abuse    NOTABU
# Name: 1, dtype: object

# %%
dataset.iloc[2]
# Out:
# id        16820
# abuse    NOTABU
# Name: 2, dtype: object

# %%
dataset.keys()
# Out:
# Index(['id', 'abuse'], dtype='object')
